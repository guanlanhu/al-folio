# %% [markdown]
# <a href="https://colab.research.google.com/github/guanlanhu/al-folio/blob/master/Part_2_Data_Modeling_and_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture Module 2: Making Choices about Data Representation and Processing
#
# ## LinkedIn Social Analysis
#
# Our second module explores concepts in:
#
# * Designing data representations to capture important relationships
# * Reasoning over graphs
# * Exploring and traversing graphs
# * Performance implications of design choices
# * Techniques for indexing, parallelism, and sequence
#
# It sets the stage for Module 3, which focuses on cloud/cluster-compute data processing.

# %% [markdown]
# ### Preliminaries
#
# We'll use MongoDB on the cloud as a sample NoSQL database

# %%
# !pip3 install pymongo[tls,srv]
# !pip3 install swifter
# !pip3 install lxml
# !pip install googledrivedownloader
# Out:
# Requirement already satisfied: pymongo[srv,tls] in /usr/local/lib/python3.6/dist-packages (3.11.2)
# Collecting dnspython<2.0.0,>=1.16.0; extra == "srv"
#   Downloading https://files.pythonhosted.org/packages/ec/d3/3aa0e7213ef72b8585747aa0e271a9523e713813b9a20177ebe1e939deb0/dnspython-1.16.0-py2.py3-none-any.whl (188kB)
#      |████████████████████████████████| 194kB 5.7MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-1.16.0
# Collecting swifter
#   Downloading https://files.pythonhosted.org/packages/f4/3b/04bf42b94a22725241b47e0256458cde11f86f97572dd824e011f1ea8b20/swifter-1.0.7.tar.gz (633kB)
#      |████████████████████████████████| 634kB 4.2MB/s
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (1.1.5)
# Collecting psutil>=5.6.6
#   Downloading https://files.pythonhosted.org/packages/da/82/56cd16a4c5f53e3e5dd7b2c30d5c803e124f218ebb644ca9c30bc907eadd/psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291kB)
#      |████████████████████████████████| 296kB 8.7MB/s
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (4.41.1)
# Requirement already satisfied: ipywidgets>=7.0.0cloudpickle>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from swifter) (7.6.3)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (0.8.1)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from swifter) (3.3.0)
# Collecting modin[ray]>=0.8.1.1
#   Downloading https://files.pythonhosted.org/packages/d0/9d/591b902668ef56fda55723c22cfe15a1986536d6c24cfbf65501ed9cf35e/modin-0.8.3-py3-none-manylinux1_x86_64.whl (564kB)
#      |████████████████████████████████| 573kB 11.7MB/s
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=1.0.0->swifter) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=1.0.0->swifter) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=1.0.0->swifter) (2018.9)
# Collecting partd>=0.3.10; extra == "dataframe"
#   Downloading https://files.pythonhosted.org/packages/44/e1/68dbe731c9c067655bff1eca5b7d40c20ca4b23fd5ec9f3d17e201a6f36b/partd-1.1.0-py3-none-any.whl
# Collecting fsspec>=0.6.0; extra == "dataframe"
#   Downloading https://files.pythonhosted.org/packages/ec/80/72ac0982cc833945fada4b76c52f0f65435ba4d53bc9317d1c70b5f7e7d5/fsspec-0.8.5-py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 7.8MB/s
# Requirement already satisfied: toolz>=0.7.3; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (4.3.3)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (5.1.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (1.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach>=3.1.1->swifter) (20.9)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Collecting pyarrow==1.0; extra == "ray"
#   Downloading https://files.pythonhosted.org/packages/a1/0a/a89de6d747c4698af128a46398703e3d1889f196478fd94a4e16bd1b5c65/pyarrow-1.0.0-cp36-cp36m-manylinux2014_x86_64.whl (17.2MB)
#      |████████████████████████████████| 17.2MB 1.3MB/s
# Collecting ray>=1.0.0; extra == "ray"
#   Downloading https://files.pythonhosted.org/packages/fa/e5/0ff593f053ff4fa2a582961272ef893c21d268d3c2c52ff1e7effd891e48/ray-1.1.0-cp36-cp36m-manylinux2014_x86_64.whl (48.5MB)
#      |████████████████████████████████| 48.5MB 62kB/s
# Collecting locket
#   Downloading https://files.pythonhosted.org/packages/50/b8/e789e45b9b9c2db75e9d9e6ceb022c8d1d7e49b2c085ce8c05600f90a96b/locket-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (5.3.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (5.3.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (53.0.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.7.5)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (2.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach>=3.1.1->swifter) (2.4.7)
# Collecting colorful
#   Downloading https://files.pythonhosted.org/packages/b0/8e/e386e248266952d24d73ed734c2f5513f34d9557032618c8910e605dfaf6/colorful-0.5.4-py2.py3-none-any.whl (201kB)
#      |████████████████████████████████| 204kB 35.0MB/s
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (1.32.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (3.13)
# Collecting py-spy>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/0c/b7/2056a6f06adb93f679f2a1e415dd33219b7c66ba69b8fd2ff1668b8064ed/py_spy-0.3.4-py2.py3-none-manylinux1_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 33.7MB/s
# Collecting opencensus
#   Downloading https://files.pythonhosted.org/packages/e2/d6/b952f11b29c3a0cbec5620de3c4260cecd8c4329d83e91587edb48691e15/opencensus-0.7.12-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 53.0MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (3.0.12)
# Collecting aiohttp-cors
#   Downloading https://files.pythonhosted.org/packages/13/e7/e436a0c0eb5127d8b491a9b83ecd2391c6ff7dcd5548dfaec2080a2340fd/aiohttp_cors-0.7.0-py3-none-any.whl
# Collecting gpustat
#   Downloading https://files.pythonhosted.org/packages/b4/69/d8c849715171aeabd61af7da080fdc60948b5a396d2422f1f4672e43d008/gpustat-0.6.0.tar.gz (78kB)
#      |████████████████████████████████| 81kB 7.9MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (1.0.2)
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/ad/e6/d4b6235d776c9b33f853e603efede5aac5a34f71ca9d3877adb30492eb4e/aiohttp-3.7.3-cp36-cp36m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 12.5MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (2.23.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (7.1.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (3.12.4)
# Collecting redis>=3.5.0
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 1.3MB/s
# Collecting aioredis
#   Downloading https://files.pythonhosted.org/packages/b0/64/1b1612d0a104f21f80eb4c6e1b6075f2e6aba8e228f46f229cfd3fdac859/aioredis-1.3.1-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 506kB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (2.11.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.9.2)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (1.5.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (22.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.2.5)
# Collecting opencensus-context==0.1.2
#   Downloading https://files.pythonhosted.org/packages/f1/33/990f1bd9e7ee770fc8d3c154fc24743a96f16a0e49e14e1b7540cc2fdd93/opencensus_context-0.1.2-py2.py3-none-any.whl
# Requirement already satisfied: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (1.16.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from gpustat->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (7.352.0)
# Collecting blessings>=1.6
#   Downloading https://files.pythonhosted.org/packages/03/74/489f85a78247609c6b4f13733cbf3ba0d864b11aa565617b645d6fdf2a4a/blessings-1.7-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (3.7.4.3)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (3.0.4)
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (20.3.0)
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/da/08/52b26b44bce7b818b410aee37c5e424c9ea420c557bca97dc2adac29b151/yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293kB)
#      |████████████████████████████████| 296kB 46.3MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/a1/35/b22524d6b9cacfb4c5eff413a069bbc17c6ea628e54da5c6c989998ced5f/multidict-5.1.0-cp36-cp36m-manylinux2014_x86_64.whl (141kB)
#      |████████████████████████████████| 143kB 24.3MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (1.24.3)
# Collecting hiredis
#   Downloading https://files.pythonhosted.org/packages/ed/7d/6acf1c8d4f2fb327ff6feec000b4c56a20628fbe966a4c7cd16c0b80343c/hiredis-1.1.0-cp36-cp36m-manylinux2010_x86_64.whl (61kB)
#      |████████████████████████████████| 61kB 4.5MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (1.4.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0cloudpickle>=0.2.2->swifter) (0.3)
# Collecting contextvars; python_version >= "3.6" and python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (1.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (1.52.0)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 6.6MB/s
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray>=1.0.0; extra == "ray"->modin[ray]>=0.8.1.1->swifter) (0.4.8)
# Building wheels for collected packages: swifter, gpustat, idna-ssl, contextvars
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.0.7-cp36-none-any.whl size=13977 sha256=d7258f98d4f13422fd8d00ea70e707cec95de07f2db62b1644b262606d22ad40
#   Stored in directory: /root/.cache/pip/wheels/99/58/39/5b59c5f4d66ce67bf55f0178e0940c964e89e9f60d70376a37
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-cp36-none-any.whl size=12622 sha256=a5376ac5aaee6ae49fe78db66714f033604864f7f19e273b0de8a88f579467fc
#   Stored in directory: /root/.cache/pip/wheels/48/b4/d5/fb5b7f1d040f2ff20687e3bad6867d63155dbde5a7c10f4293
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3163 sha256=8b10b6a8522a60cb07cdea74f2fcdab361a60f9401c1fb58639bffd02cb9bc04
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7667 sha256=98299b35e2fd22acb0dc9376cb203150669dec9b8f542d30be47a6a46f24802b
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built swifter gpustat idna-ssl contextvars
# Installing collected packages: psutil, pyarrow, colorful, py-spy, immutables, contextvars, opencensus-context, opencensus, colorama, idna-ssl, multidict, yarl, async-timeout, aiohttp, aiohttp-cors, blessings, gpustat, redis, hiredis, aioredis, ray, modin, swifter, locket, partd, fsspec
#   Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Found existing installation: pyarrow 0.14.1
#     Uninstalling pyarrow-0.14.1:
#       Successfully uninstalled pyarrow-0.14.1
# Successfully installed aiohttp-3.7.3 aiohttp-cors-0.7.0 aioredis-1.3.1 async-timeout-3.0.1 blessings-1.7 colorama-0.4.4 colorful-0.5.4 contextvars-2.4 fsspec-0.8.5 gpustat-0.6.0 hiredis-1.1.0 idna-ssl-1.1.0 immutables-0.14 locket-0.2.1 modin-0.8.3 multidict-5.1.0 opencensus-0.7.12 opencensus-context-0.1.2 partd-1.1.0 psutil-5.8.0 py-spy-0.3.4 pyarrow-1.0.0 ray-1.1.0 redis-3.5.3 swifter-1.0.7 yarl-1.6.3
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (4.2.6)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (0.4)

# %%
import pandas as pd
import numpy as np

# JSON parsing
import json

# HTML parsing
from lxml import etree
import urllib

# SQLite RDBMS
import sqlite3

# Time conversions
import time

# Parallel processing
import swifter

# NoSQL DB
from pymongo import MongoClient
from pymongo.errors import DuplicateKeyError, OperationFailure

# %% [markdown]
# ## Our Example Dataset
#
# A crawl of LinkedIn, stored as a sequence of JSON objects (one per line).  Here's a scan through the sample dataset, taken from Kaggle (https://www.kaggle.com/linkedindata/linkedin-crawled-profiles-dataset).

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1CtSFvqTM-JTxWu7-lfGYba1tLYkcqIZC',
                                    dest_path='/content/linkedin_small.json.txt')
# Out:
# Downloading 1CtSFvqTM-JTxWu7-lfGYba1tLYkcqIZC into /content/linkedin_small.json.txt... Done.

# %%
# %%time
# 100K records from linkedin
linked_in = open('/content/linkedin_small.json.txt')

people = []

for line in linked_in:
    person = json.loads(line)
    people.append(person)

people_df = pd.DataFrame(people)
print ("%d records"%len(people_df))

people_df
# Out:
# 100000 records
# CPU times: user 9.32 s, sys: 1.97 s, total: 11.3 s
# Wall time: 11.4 s

# %% [markdown]
# ## NoSQL storage

# %% [markdown]
# For this part we will give you read-only access to our copy of MongoDB.  To do it yourself, please sign up at:
#
# https://www.mongodb.com/cloud
#
# Click on "Get started", sign up, agree to terms of service, and create a new cluster on AWS free tier (Northern Virginia).
#
# Eventually you'll need to tell MongoDB to add your IP address (so you can talk to the machine) and you'll need to create a database called 'linkedin'.

# %%
# Store in MongoDB and in an in-memory list

START = 0
# We already have the data loaded into MongoDB, so we won't actually
# read all 37000 records.  We'll test by reading + writing the first
# 37 though!
LIMIT = 37  #000

client = MongoClient('mongodb+srv://cis545:1course4all@cluster0-cy1yu.mongodb.net/test?retryWrites=true&w=majority')

linkedin_db = client['linkedin']
linked_in = open('/content/linkedin_small.json.txt')

# Build a list of the JSON elements
list_for_comparison = []

people = 0
for line in linked_in:
    person = json.loads(line)
    if people >= START:
        try:
            list_for_comparison.append(person)
            linkedin_db.posts.insert_one(person)
        except DuplicateKeyError:
            pass
        except OperationFailure:
            # If the above still uses our cluster, you'll get this error in
            # attempting to write to our MongoDB client
            pass
    people = people + 1
    if people > LIMIT:
        break

# %%
# Two ways of looking up skills, one based on an in-memory
# list, one based on MongoDB queries

def find_skills_in_list(skill):
    for post in list_for_comparison:
        if 'skills' in post:
            skills = post['skills']
            for this_skill in skills:
                if this_skill == skill:
                    return post
    return None

def find_skills_in_mongodb(skill):
    return linkedin_db.posts.find_one({'skills': skill})

# %%
# %%time
find_skills_in_list('Marketing')

# %%
# %%time
find_skills_in_mongodb('Marketing')

# %% [markdown]
# ## Designing a relational schema from hierarchical data
#
# Given that we already have a predefined set of fields / attributes / features, we don't need to spend a lot of time defining our table *schemas*, except that we need to unnest data.
#
# * Nested relationships can be captured by creating a second table, which has a **foreign key** pointing to the identifier (key) for the main (parent) table.
# * Ordered lists can be captured by encoding an index number or row number.

# %%
'''
Simple code to pull out data from JSON and load into sqllite
'''
linked_in = open('/content/linkedin_small.json.txt')

START = 0
LIMIT = 10000

def get_df(rel):
    ret = pd.DataFrame(rel).fillna('')
    for k in ret.keys():
        ret[k] = ret[k].astype(str)
    return ret

def extract_relation(rel, name):
    '''
    Pull out a nested list that has a key, and return it as a list
    of dictionaries suitable for treating as a relation / dataframe
    '''
    # We'll return a list
    ret  = []
    if name in rel:
        ret2 = rel.pop(name)
        try:
            # Try to parse the string as a dictionary
            ret2 = json.loads(ret2.replace('\'','\"'))
        except:
            # If we get an error in parsing, we'll leave as a string
            pass

        # If it's a dictionary, add it to our return results after
        # adding a key to the parent
        if isinstance(ret2, dict):
            item = ret2
            item['person'] = rel['_id']
            ret.append(item)
        else:
            # If it's a list, iterate over each item
            index = 0
            for r in ret2:
                item = r
                if not isinstance(item, dict):
                    item = {'person': rel['_id'], 'value': item}
                else:
                    item['person'] = rel['_id']

                # A fix to a typo in the data
                if 'affilition' in item:
                    item['affiliation'] = item.pop('affilition')

                item['pos'] = index
                index = index + 1
                ret.append(item)
    return ret


names = []
people = []
groups = []
education = []
skills = []
experience = []
honors = []
also_view = []
events = []


conn = sqlite3.connect('linkedin.db')

lines = []
i = 1
for line in linked_in:
    if i > START + LIMIT:
        break
    elif i >= START:
        person = json.loads(line)

        # By inspection, all of these are nested dictionary or list content
        nam = extract_relation(person, 'name')
        edu = extract_relation(person, 'education')
        grp = extract_relation(person, 'group')
        skl = extract_relation(person, 'skills')
        exp  = extract_relation(person, 'experience')
        hon = extract_relation(person, 'honors')
        als = extract_relation(person, 'also_view')
        eve = extract_relation(person, 'events')

        # This doesn't seem relevant and it's the only
        # non-string field that's sometimes null
        if 'interval' in person:
            person.pop('interval')

        lines.append(person)
        names = names + nam
        education = education + edu
        groups  = groups + grp
        skills = skills + skl
        experience = experience + exp
        honors = honors + hon
        also_view = also_view + als
        events = events + eve

    i = i + 1

people_df = get_df(pd.DataFrame(lines))
names_df = get_df(pd.DataFrame(names))
education_df = get_df(pd.DataFrame(education))
groups_df = get_df(pd.DataFrame(groups))
skills_df = get_df(pd.DataFrame(skills))
experience_df = get_df(pd.DataFrame(experience))
honors_df = get_df(pd.DataFrame(honors))
also_view_df = get_df(pd.DataFrame(also_view))
events_df = get_df(pd.DataFrame(events))

# %%
# Save these to the SQLite database

people_df.to_sql('people', conn, if_exists='replace', index=False)
names_df.to_sql('names', conn, if_exists='replace', index=False)
education_df.to_sql('education', conn, if_exists='replace', index=False)
groups_df.to_sql('groups', conn, if_exists='replace', index=False)
skills_df.to_sql('skills', conn, if_exists='replace', index=False)
experience_df.to_sql('experience', conn, if_exists='replace', index=False)
honors_df.to_sql('honors', conn, if_exists='replace', index=False)
also_view_df.to_sql('also_view', conn, if_exists='replace', index=False)
events_df.to_sql('events', conn, if_exists='replace', index=False)

# %%
groups_df
# Out:
#                                              affilition  ...                                             member
# 0     ['ASMALLWORLD.net', 'Biomarker Research & Exec...  ...
# 1     ['Big Data, Low Latency', "Experts Answer's", ...  ...
# 2     ['AeSI Alumni Association', 'Aircraft Electron...  ...  Member of Project Management Institute, Life M...
# 3     ['Canadian Marketing Association', 'LeadingLoy...  ...
# 4     ['CFA Institute Candidates', 'Economist Intell...  ...                          Associate Member of SAMRA
# ...                                                 ...  ...                                                ...
# 6331  ['EADA Alumni', 'Entrepreneurs Network Barcelo...  ...                                        EADA Alumni
# 6332  ['CUDA Developers', 'CUDA Users Group', 'Data ...  ...
# 6333  ['Sony Ericsson Global', 'WE LOVE ADVERTISING'...  ...
# 6334  ['COMPANY PHARMA TALENT', 'Chemical / O&G Oppo...  ...
# 6335  ['ArcelorMittal Group', 'Basket and Talent', '...  ...
#
# [6336 rows x 3 columns]

# %%
pd.read_sql_query('select _id, org from people join experience on _id=person', conn)
# Out:
#                         _id                                     org
# 0                  in-00001          Albert Einstein Medical Center
# 1                  in-00001                     Columbia University
# 2                  in-00001                     Johnson and Johnson
# 3                  in-00001  Memorial Sloan Kettering Cancer Center
# 4                  in-00001         Sahlgrenska University Hospital
# ...                     ...                                     ...
# 46106  in-albertocastellano                                   Reply
# 46107  in-albertocastellano                             Vodafone IT
# 46108      in-albertocesani                             Atari Games
# 46109      in-albertocesani                          Koch Media srl
# 46110      in-albertocesani                   Namco Bandai Partners
#
# [46111 rows x 2 columns]

# %%
pd.read_sql_query("select _id, group_concat(org) as experience " +\
                  " from people left join experience on _id=person group by _id", conn)
# Out:
#                          _id                                         experience
# 0                in-00000001                                               None
# 1                   in-00001  Albert Einstein Medical Center,Columbia Univer...
# 2                   in-00006  UCSF,Wyss Institute for Biologically Inspired ...
# 3           in-000montgomery  000Montgomery.Com,<Advertising Company>,<Adver...
# 4         in-000vijaychauhan                                               None
# ...                      ...                                                ...
# 9995      in-albertocarimati  BASF,Basf Italia,Lonza Polymer and,Lonza Singa...
# 9996      in-albertocarrasco  Glassdrive España,Saint-Gobain Glassdrive Espa...
# 9997  in-albertocarreroderoa  ArcelorMittal,Corporacion Alimentaria Penasant...
# 9998    in-albertocastellano   Amadeus,Amadeus IT Group,Astek,Reply,Vodafone IT
# 9999        in-albertocesani   Atari Games,Koch Media srl,Namco Bandai Partners
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Views
#
# The following code starts a transaction (we can either `commit` or `rollback` at the end), removes an existing view, and creates a new one.

# %%
conn.execute('begin transaction')
conn.execute('drop view if exists people_experience')
conn.execute("create view people_experience as select _id, group_concat(org) as experience " +\
                  " from people left join experience on _id=person group by _id")
conn.execute('commit')

# Treat the view as a table, see what's there
pd.read_sql_query('select * from people_experience', conn)
# Out:
#                          _id                                         experience
# 0                in-00000001                                               None
# 1                   in-00001  Albert Einstein Medical Center,Columbia Univer...
# 2                   in-00006  UCSF,Wyss Institute for Biologically Inspired ...
# 3           in-000montgomery  000Montgomery.Com,<Advertising Company>,<Adver...
# 4         in-000vijaychauhan                                               None
# ...                      ...                                                ...
# 9995      in-albertocarimati  BASF,Basf Italia,Lonza Polymer and,Lonza Singa...
# 9996      in-albertocarrasco  Glassdrive España,Saint-Gobain Glassdrive Espa...
# 9997  in-albertocarreroderoa  ArcelorMittal,Corporacion Alimentaria Penasant...
# 9998    in-albertocastellano   Amadeus,Amadeus IT Group,Astek,Reply,Vodafone IT
# 9999        in-albertocesani   Atari Games,Koch Media srl,Namco Bandai Partners
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Deep Dive: Converting a Complex Tree to Relations
#
# Now that we've seen the basics of taking hierarchical data and turning it into relations, let's put the LinkedIn data on the stack for a brief time, and try a more difficult exercise representing (and querying) tree-structured data.
#
# We'll take the HTML data from Wikipedia pages, seen in the Lecture 1 Notebook, and "shred" the HTML into tables.
#
# Briefly, if we think of the HTML as a tree of nodes, e.g.:
#
# ```
#    <html>
#    |   |
# <head> <body>
#    |    |   |
# <title> <h1> <p>
#    |     |    \
#  ABC    ABC    DEF
# ```
#
# Then we can give a **node ID** to each node in the tree; an a **position** (0, 1, ...) to each sibling at a level in the tree.  We will "slice" the tree into segments, each of which becomes a row in a table.  The row will include the node ID, the node label or type ("h1" or "text()"), the node value if the type is text(), and the position.

# %%
# Recursively crawl the node and add rows to the html_tree table
def traverse_html(node, parent, pos, node_df):
    if node.text:
        text_id = len(node_df)
        entry = {'node_id': text_id, 'parent_node_id': parent, 'type_or_label': 'text()', 'pos': pos, 'value': node.text}
        print (str(entry))
        html_tree_df = node_df.append(entry, ignore_index=True)

    if node.tag:
        node_id = len(node_df)
        entry = {'node_id': node_id, 'parent_node_id': parent, 'type_or_label': node.tag, 'pos': pos, 'value': ''}
        node_df = node_df.append(entry, ignore_index=True)
        print (str(entry))
        index = 0
        for child in list(node):
            (child_id, node_df) = traverse_html(child, node_id, index, node_df)
            index = index + 1

    if node.tail:
        text_id = len(node_df)
        entry = {'node_id': text_id, 'parent_node_id': parent, 'type_or_label': 'text()', 'pos': pos, 'value': node.tail}
        print (str(entry))
        node_df = node_df.append(entry, ignore_index=True)
    return (node_id, node_df)

pages_df = pd.DataFrame(columns=['url','root_id'])
node_df = pd.DataFrame(columns=['node_id','parent_node_id','type_or_label','pos','value'])


# Crawl these pages
page_list = ['https://en.wikipedia.org/wiki/Tim_Cook',
            'https://en.wikipedia.org/wiki/Chan_Zuckerberg_Initiative']
for page in page_list:
    page_content = urllib.request.urlopen(page).read()
    page_tree = etree.HTML(page_content)
    (root_node,node_df) = traverse_html(page_tree, None, 0, node_df)
    pages_df = pages_df.append({'url': page, 'root_id': root_node}, ignore_index=True)

pages_df
# Out:
# Streaming output truncated to the last 5000 lines.
# {'node_id': 3636, 'parent_node_id': 3635, 'type_or_label': 'text()', 'pos': 0, 'value': 'DiDi'}
# {'node_id': 3636, 'parent_node_id': 3635, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3637, 'parent_node_id': 3615, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3638, 'parent_node_id': 3615, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3639, 'parent_node_id': 3638, 'type_or_label': 'i', 'pos': 0, 'value': ''}
# {'node_id': 3640, 'parent_node_id': 3639, 'type_or_label': 'text()', 'pos': 0, 'value': 'Digital Ocean'}
# {'node_id': 3640, 'parent_node_id': 3639, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3641, 'parent_node_id': 3615, 'type_or_label': 'text()', 'pos': 4, 'value': '\n'}
# {'node_id': 3642, 'parent_node_id': 3615, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 3643, 'parent_node_id': 3642, 'type_or_label': 'text()', 'pos': 0, 'value': 'iFund'}
# {'node_id': 3643, 'parent_node_id': 3642, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3644, 'parent_node_id': 3615, 'type_or_label': 'text()', 'pos': 5, 'value': '\n'}
# {'node_id': 3645, 'parent_node_id': 3615, 'type_or_label': 'li', 'pos': 6, 'value': ''}
# {'node_id': 3646, 'parent_node_id': 3645, 'type_or_label': 'text()', 'pos': 0, 'value': 'Imagination'}
# {'node_id': 3646, 'parent_node_id': 3645, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3647, 'parent_node_id': 3615, 'type_or_label': 'text()', 'pos': 6, 'value': '\n'}
# {'node_id': 3648, 'parent_node_id': 3615, 'type_or_label': 'li', 'pos': 7, 'value': ''}
# {'node_id': 3649, 'parent_node_id': 3648, 'type_or_label': 'text()', 'pos': 0, 'value': 'Rockstar Consortium'}
# {'node_id': 3649, 'parent_node_id': 3648, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3650, 'parent_node_id': 3614, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3651, 'parent_node_id': 3498, 'type_or_label': 'div', 'pos': 2, 'value': ''}
# {'node_id': 3652, 'parent_node_id': 2952, 'type_or_label': 'tr', 'pos': 5, 'value': ''}
# {'node_id': 3653, 'parent_node_id': 3652, 'type_or_label': 'text()', 'pos': 0, 'value': 'Related'}
# {'node_id': 3653, 'parent_node_id': 3652, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3654, 'parent_node_id': 3652, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3655, 'parent_node_id': 3654, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3655, 'parent_node_id': 3654, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3656, 'parent_node_id': 3655, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 3657, 'parent_node_id': 3656, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3658, 'parent_node_id': 3657, 'type_or_label': 'text()', 'pos': 0, 'value': 'Advertising'}
# {'node_id': 3658, 'parent_node_id': 3657, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3659, 'parent_node_id': 3657, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3660, 'parent_node_id': 3657, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 3661, 'parent_node_id': 3660, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3662, 'parent_node_id': 3661, 'type_or_label': 'text()', 'pos': 0, 'value': '1984'}
# {'node_id': 3662, 'parent_node_id': 3661, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3663, 'parent_node_id': 3660, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3664, 'parent_node_id': 3660, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3665, 'parent_node_id': 3664, 'type_or_label': 'text()', 'pos': 0, 'value': 'Think different'}
# {'node_id': 3665, 'parent_node_id': 3664, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3666, 'parent_node_id': 3660, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3667, 'parent_node_id': 3660, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3668, 'parent_node_id': 3667, 'type_or_label': 'text()', 'pos': 0, 'value': 'Get a Mac'}
# {'node_id': 3668, 'parent_node_id': 3667, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3669, 'parent_node_id': 3660, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3670, 'parent_node_id': 3660, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3671, 'parent_node_id': 3670, 'type_or_label': 'text()', 'pos': 0, 'value': 'iPods'}
# {'node_id': 3671, 'parent_node_id': 3670, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3672, 'parent_node_id': 3660, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3673, 'parent_node_id': 3660, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3674, 'parent_node_id': 3673, 'type_or_label': 'text()', 'pos': 0, 'value': 'Product Red'}
# {'node_id': 3674, 'parent_node_id': 3673, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3675, 'parent_node_id': 3656, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3676, 'parent_node_id': 3656, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3677, 'parent_node_id': 3676, 'type_or_label': 'text()', 'pos': 0, 'value': 'Campus'}
# {'node_id': 3677, 'parent_node_id': 3676, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3678, 'parent_node_id': 3676, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3679, 'parent_node_id': 3676, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 3680, 'parent_node_id': 3679, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3681, 'parent_node_id': 3680, 'type_or_label': 'text()', 'pos': 0, 'value': 'Park'}
# {'node_id': 3681, 'parent_node_id': 3680, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3682, 'parent_node_id': 3679, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3683, 'parent_node_id': 3679, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3684, 'parent_node_id': 3683, 'type_or_label': 'text()', 'pos': 0, 'value': 'University'}
# {'node_id': 3684, 'parent_node_id': 3683, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3685, 'parent_node_id': 3656, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3686, 'parent_node_id': 3656, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3687, 'parent_node_id': 3686, 'type_or_label': 'text()', 'pos': 0, 'value': 'Design'}
# {'node_id': 3687, 'parent_node_id': 3686, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3688, 'parent_node_id': 3686, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3689, 'parent_node_id': 3686, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 3690, 'parent_node_id': 3689, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3691, 'parent_node_id': 3690, 'type_or_label': 'text()', 'pos': 0, 'value': 'IDg'}
# {'node_id': 3691, 'parent_node_id': 3690, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3692, 'parent_node_id': 3689, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3693, 'parent_node_id': 3689, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3694, 'parent_node_id': 3693, 'type_or_label': 'text()', 'pos': 0, 'value': 'Typography'}
# {'node_id': 3694, 'parent_node_id': 3693, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3695, 'parent_node_id': 3689, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3696, 'parent_node_id': 3689, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3697, 'parent_node_id': 3696, 'type_or_label': 'text()', 'pos': 0, 'value': 'Book'}
# {'node_id': 3697, 'parent_node_id': 3696, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3698, 'parent_node_id': 3656, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3699, 'parent_node_id': 3656, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3700, 'parent_node_id': 3699, 'type_or_label': 'text()', 'pos': 0, 'value': 'History'}
# {'node_id': 3700, 'parent_node_id': 3699, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3701, 'parent_node_id': 3699, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3702, 'parent_node_id': 3699, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 3703, 'parent_node_id': 3702, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3704, 'parent_node_id': 3703, 'type_or_label': 'text()', 'pos': 0, 'value': 'Codenames'}
# {'node_id': 3704, 'parent_node_id': 3703, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3705, 'parent_node_id': 3702, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3706, 'parent_node_id': 3702, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3707, 'parent_node_id': 3706, 'type_or_label': 'text()', 'pos': 0, 'value': 'Community'}
# {'node_id': 3707, 'parent_node_id': 3706, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3708, 'parent_node_id': 3706, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3709, 'parent_node_id': 3706, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 3710, 'parent_node_id': 3709, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3711, 'parent_node_id': 3710, 'type_or_label': 'text()', 'pos': 0, 'value': 'Evangelist'}
# {'node_id': 3711, 'parent_node_id': 3710, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3712, 'parent_node_id': 3709, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3713, 'parent_node_id': 3709, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3714, 'parent_node_id': 3713, 'type_or_label': 'text()', 'pos': 0, 'value': 'Fellow'}
# {'node_id': 3714, 'parent_node_id': 3713, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3715, 'parent_node_id': 3709, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3716, 'parent_node_id': 3709, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3717, 'parent_node_id': 3716, 'type_or_label': 'text()', 'pos': 0, 'value': 'Master'}
# {'node_id': 3717, 'parent_node_id': 3716, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3718, 'parent_node_id': 3702, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3719, 'parent_node_id': 3702, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3720, 'parent_node_id': 3719, 'type_or_label': 'text()', 'pos': 0, 'value': 'Criticism'}
# {'node_id': 3720, 'parent_node_id': 3719, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3721, 'parent_node_id': 3702, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3722, 'parent_node_id': 3702, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3723, 'parent_node_id': 3722, 'type_or_label': 'text()', 'pos': 0, 'value': 'Litigation'}
# {'node_id': 3723, 'parent_node_id': 3722, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3724, 'parent_node_id': 3722, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3725, 'parent_node_id': 3722, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 3726, 'parent_node_id': 3725, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3727, 'parent_node_id': 3726, 'type_or_label': 'text()', 'pos': 0, 'value': 'FBI–Apple encryption dispute'}
# {'node_id': 3727, 'parent_node_id': 3726, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3728, 'parent_node_id': 3702, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3729, 'parent_node_id': 3702, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3730, 'parent_node_id': 3729, 'type_or_label': 'text()', 'pos': 0, 'value': 'iOS app approvals'}
# {'node_id': 3730, 'parent_node_id': 3729, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3731, 'parent_node_id': 3656, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3732, 'parent_node_id': 3656, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3733, 'parent_node_id': 3732, 'type_or_label': 'text()', 'pos': 0, 'value': 'Artistic depictions of Steve Jobs'}
# {'node_id': 3733, 'parent_node_id': 3732, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3734, 'parent_node_id': 3655, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3735, 'parent_node_id': 2952, 'type_or_label': 'tr', 'pos': 6, 'value': ''}
# {'node_id': 3736, 'parent_node_id': 3735, 'type_or_label': 'text()', 'pos': 0, 'value': 'People'}
# {'node_id': 3736, 'parent_node_id': 3735, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3737, 'parent_node_id': 3735, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3738, 'parent_node_id': 3737, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3739, 'parent_node_id': 3737, 'type_or_label': 'table', 'pos': 1, 'value': ''}
# {'node_id': 3740, 'parent_node_id': 3739, 'type_or_label': 'tbody', 'pos': 0, 'value': ''}
# {'node_id': 3741, 'parent_node_id': 3740, 'type_or_label': 'tr', 'pos': 0, 'value': ''}
# {'node_id': 3742, 'parent_node_id': 3741, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3743, 'parent_node_id': 3742, 'type_or_label': 'text()', 'pos': 0, 'value': 'Executives'}
# {'node_id': 3743, 'parent_node_id': 3742, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3744, 'parent_node_id': 3741, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3745, 'parent_node_id': 3744, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3746, 'parent_node_id': 3744, 'type_or_label': 'table', 'pos': 1, 'value': ''}
# {'node_id': 3747, 'parent_node_id': 3746, 'type_or_label': 'tbody', 'pos': 0, 'value': ''}
# {'node_id': 3748, 'parent_node_id': 3747, 'type_or_label': 'tr', 'pos': 0, 'value': ''}
# {'node_id': 3749, 'parent_node_id': 3748, 'type_or_label': 'text()', 'pos': 0, 'value': 'Current'}
# {'node_id': 3749, 'parent_node_id': 3748, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3750, 'parent_node_id': 3748, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3751, 'parent_node_id': 3750, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3751, 'parent_node_id': 3750, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3752, 'parent_node_id': 3751, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 3753, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3754, 'parent_node_id': 3753, 'type_or_label': 'text()', 'pos': 0, 'value': 'Tim Cook'}
# {'node_id': 3754, 'parent_node_id': 3753, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3755, 'parent_node_id': 3753, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3756, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3757, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3758, 'parent_node_id': 3757, 'type_or_label': 'text()', 'pos': 0, 'value': 'Jeff Williams'}
# {'node_id': 3758, 'parent_node_id': 3757, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3759, 'parent_node_id': 3757, 'type_or_label': 'text()', 'pos': 0, 'value': ' (COO)'}
# {'node_id': 3760, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3761, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3762, 'parent_node_id': 3761, 'type_or_label': 'text()', 'pos': 0, 'value': 'Luca Maestri'}
# {'node_id': 3762, 'parent_node_id': 3761, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3763, 'parent_node_id': 3761, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CFO)'}
# {'node_id': 3764, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3765, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3766, 'parent_node_id': 3765, 'type_or_label': 'text()', 'pos': 0, 'value': 'Katherine Adams'}
# {'node_id': 3766, 'parent_node_id': 3765, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3767, 'parent_node_id': 3765, 'type_or_label': 'text()', 'pos': 0, 'value': ' (General Counsel)'}
# {'node_id': 3768, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3769, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3770, 'parent_node_id': 3769, 'type_or_label': 'text()', 'pos': 0, 'value': 'Eddy Cue'}
# {'node_id': 3770, 'parent_node_id': 3769, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3771, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 4, 'value': '\n'}
# {'node_id': 3772, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 3773, 'parent_node_id': 3772, 'type_or_label': 'text()', 'pos': 0, 'value': 'Craig Federighi'}
# {'node_id': 3773, 'parent_node_id': 3772, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3774, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 5, 'value': '\n'}
# {'node_id': 3775, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 6, 'value': ''}
# {'node_id': 3776, 'parent_node_id': 3775, 'type_or_label': 'text()', 'pos': 0, 'value': 'Isabel Ge Mahe'}
# {'node_id': 3776, 'parent_node_id': 3775, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3777, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 6, 'value': '\n'}
# {'node_id': 3778, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 7, 'value': ''}
# {'node_id': 3779, 'parent_node_id': 3778, 'type_or_label': 'text()', 'pos': 0, 'value': 'John Giannandrea'}
# {'node_id': 3779, 'parent_node_id': 3778, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3780, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 7, 'value': '\n'}
# {'node_id': 3781, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 8, 'value': ''}
# {'node_id': 3782, 'parent_node_id': 3781, 'type_or_label': 'text()', 'pos': 0, 'value': 'Lisa Jackson'}
# {'node_id': 3782, 'parent_node_id': 3781, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3783, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 8, 'value': '\n'}
# {'node_id': 3784, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 9, 'value': 'Sabih Khan'}
# {'node_id': 3784, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 9, 'value': ''}
# {'node_id': 3785, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 9, 'value': '\n'}
# {'node_id': 3786, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 10, 'value': 'Tor Myhren'}
# {'node_id': 3786, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 10, 'value': ''}
# {'node_id': 3787, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 10, 'value': '\n'}
# {'node_id': 3788, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 11, 'value': ''}
# {'node_id': 3789, 'parent_node_id': 3788, 'type_or_label': 'text()', 'pos': 0, 'value': "Deirdre O'Brien"}
# {'node_id': 3789, 'parent_node_id': 3788, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3790, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 11, 'value': '\n'}
# {'node_id': 3791, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 12, 'value': 'Adrian Perica'}
# {'node_id': 3791, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 12, 'value': ''}
# {'node_id': 3792, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 12, 'value': '\n'}
# {'node_id': 3793, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 13, 'value': ''}
# {'node_id': 3794, 'parent_node_id': 3793, 'type_or_label': 'text()', 'pos': 0, 'value': 'Dan Riccio'}
# {'node_id': 3794, 'parent_node_id': 3793, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3795, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 13, 'value': '\n'}
# {'node_id': 3796, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 14, 'value': ''}
# {'node_id': 3797, 'parent_node_id': 3796, 'type_or_label': 'text()', 'pos': 0, 'value': 'Phil Schiller'}
# {'node_id': 3797, 'parent_node_id': 3796, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3798, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 14, 'value': '\n'}
# {'node_id': 3799, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 15, 'value': ''}
# {'node_id': 3800, 'parent_node_id': 3799, 'type_or_label': 'text()', 'pos': 0, 'value': 'Johny Srouji'}
# {'node_id': 3800, 'parent_node_id': 3799, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3801, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 15, 'value': '\n'}
# {'node_id': 3802, 'parent_node_id': 3752, 'type_or_label': 'text()', 'pos': 16, 'value': 'Greg Joswiak'}
# {'node_id': 3802, 'parent_node_id': 3752, 'type_or_label': 'li', 'pos': 16, 'value': ''}
# {'node_id': 3803, 'parent_node_id': 3751, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3804, 'parent_node_id': 3747, 'type_or_label': 'tr', 'pos': 1, 'value': ''}
# {'node_id': 3805, 'parent_node_id': 3804, 'type_or_label': 'text()', 'pos': 0, 'value': 'Former'}
# {'node_id': 3805, 'parent_node_id': 3804, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3806, 'parent_node_id': 3804, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3807, 'parent_node_id': 3806, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3807, 'parent_node_id': 3806, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3808, 'parent_node_id': 3807, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 3809, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3810, 'parent_node_id': 3809, 'type_or_label': 'text()', 'pos': 0, 'value': 'Michael Scott'}
# {'node_id': 3810, 'parent_node_id': 3809, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3811, 'parent_node_id': 3809, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3812, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3813, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3814, 'parent_node_id': 3813, 'type_or_label': 'text()', 'pos': 0, 'value': 'Mike Markkula'}
# {'node_id': 3814, 'parent_node_id': 3813, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3815, 'parent_node_id': 3813, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3816, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3817, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3818, 'parent_node_id': 3817, 'type_or_label': 'text()', 'pos': 0, 'value': 'John Sculley'}
# {'node_id': 3818, 'parent_node_id': 3817, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3819, 'parent_node_id': 3817, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3820, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3821, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3822, 'parent_node_id': 3821, 'type_or_label': 'text()', 'pos': 0, 'value': 'Michael Spindler'}
# {'node_id': 3822, 'parent_node_id': 3821, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3823, 'parent_node_id': 3821, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3824, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3825, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3826, 'parent_node_id': 3825, 'type_or_label': 'text()', 'pos': 0, 'value': 'Gil Amelio'}
# {'node_id': 3826, 'parent_node_id': 3825, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3827, 'parent_node_id': 3825, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3828, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 4, 'value': '\n'}
# {'node_id': 3829, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 3830, 'parent_node_id': 3829, 'type_or_label': 'text()', 'pos': 0, 'value': 'Steve Jobs'}
# {'node_id': 3830, 'parent_node_id': 3829, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3831, 'parent_node_id': 3829, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3832, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 5, 'value': '\n'}
# {'node_id': 3833, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 6, 'value': ''}
# {'node_id': 3834, 'parent_node_id': 3833, 'type_or_label': 'text()', 'pos': 0, 'value': 'Jony Ive'}
# {'node_id': 3834, 'parent_node_id': 3833, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3835, 'parent_node_id': 3833, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CDO)'}
# {'node_id': 3836, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 6, 'value': '\n'}
# {'node_id': 3837, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 7, 'value': ''}
# {'node_id': 3838, 'parent_node_id': 3837, 'type_or_label': 'text()', 'pos': 0, 'value': 'Angela Ahrendts'}
# {'node_id': 3838, 'parent_node_id': 3837, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3839, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 7, 'value': '\n'}
# {'node_id': 3840, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 8, 'value': ''}
# {'node_id': 3841, 'parent_node_id': 3840, 'type_or_label': 'text()', 'pos': 0, 'value': 'Fred D. Anderson'}
# {'node_id': 3841, 'parent_node_id': 3840, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3842, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 8, 'value': '\n'}
# {'node_id': 3843, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 9, 'value': ''}
# {'node_id': 3844, 'parent_node_id': 3843, 'type_or_label': 'text()', 'pos': 0, 'value': 'John Browett'}
# {'node_id': 3844, 'parent_node_id': 3843, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3845, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 9, 'value': '\n'}
# {'node_id': 3846, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 10, 'value': ''}
# {'node_id': 3847, 'parent_node_id': 3846, 'type_or_label': 'text()', 'pos': 0, 'value': 'Guerrino De Luca'}
# {'node_id': 3847, 'parent_node_id': 3846, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3848, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 10, 'value': '\n'}
# {'node_id': 3849, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 11, 'value': ''}
# {'node_id': 3850, 'parent_node_id': 3849, 'type_or_label': 'text()', 'pos': 0, 'value': 'Paul Deneve'}
# {'node_id': 3850, 'parent_node_id': 3849, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3851, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 11, 'value': '\n'}
# {'node_id': 3852, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 12, 'value': ''}
# {'node_id': 3853, 'parent_node_id': 3852, 'type_or_label': 'text()', 'pos': 0, 'value': 'Al Eisenstat'}
# {'node_id': 3853, 'parent_node_id': 3852, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3854, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 12, 'value': '\n'}
# {'node_id': 3855, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 13, 'value': ''}
# {'node_id': 3856, 'parent_node_id': 3855, 'type_or_label': 'text()', 'pos': 0, 'value': 'Tony Fadell'}
# {'node_id': 3856, 'parent_node_id': 3855, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3857, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 13, 'value': '\n'}
# {'node_id': 3858, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 14, 'value': ''}
# {'node_id': 3859, 'parent_node_id': 3858, 'type_or_label': 'text()', 'pos': 0, 'value': 'Scott Forstall'}
# {'node_id': 3859, 'parent_node_id': 3858, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3860, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 14, 'value': '\n'}
# {'node_id': 3861, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 15, 'value': ''}
# {'node_id': 3862, 'parent_node_id': 3861, 'type_or_label': 'text()', 'pos': 0, 'value': 'Ellen Hancock'}
# {'node_id': 3862, 'parent_node_id': 3861, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3863, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 15, 'value': '\n'}
# {'node_id': 3864, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 16, 'value': ''}
# {'node_id': 3865, 'parent_node_id': 3864, 'type_or_label': 'text()', 'pos': 0, 'value': 'Nancy R. Heinen'}
# {'node_id': 3865, 'parent_node_id': 3864, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3866, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 16, 'value': '\n'}
# {'node_id': 3867, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 17, 'value': ''}
# {'node_id': 3868, 'parent_node_id': 3867, 'type_or_label': 'text()', 'pos': 0, 'value': 'Ron Johnson'}
# {'node_id': 3868, 'parent_node_id': 3867, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3869, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 17, 'value': '\n'}
# {'node_id': 3870, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 18, 'value': ''}
# {'node_id': 3871, 'parent_node_id': 3870, 'type_or_label': 'text()', 'pos': 0, 'value': 'David Nagel'}
# {'node_id': 3871, 'parent_node_id': 3870, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3872, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 18, 'value': '\n'}
# {'node_id': 3873, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 19, 'value': ''}
# {'node_id': 3874, 'parent_node_id': 3873, 'type_or_label': 'text()', 'pos': 0, 'value': 'Peter Oppenheimer'}
# {'node_id': 3874, 'parent_node_id': 3873, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3875, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 19, 'value': '\n'}
# {'node_id': 3876, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 20, 'value': ''}
# {'node_id': 3877, 'parent_node_id': 3876, 'type_or_label': 'text()', 'pos': 0, 'value': 'Mark Papermaster'}
# {'node_id': 3877, 'parent_node_id': 3876, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3878, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 20, 'value': '\n'}
# {'node_id': 3879, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 21, 'value': ''}
# {'node_id': 3880, 'parent_node_id': 3879, 'type_or_label': 'text()', 'pos': 0, 'value': 'Jon Rubinstein'}
# {'node_id': 3880, 'parent_node_id': 3879, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3881, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 21, 'value': '\n'}
# {'node_id': 3882, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 22, 'value': ''}
# {'node_id': 3883, 'parent_node_id': 3882, 'type_or_label': 'text()', 'pos': 0, 'value': 'Bertrand Serlet'}
# {'node_id': 3883, 'parent_node_id': 3882, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3884, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 22, 'value': '\n'}
# {'node_id': 3885, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 23, 'value': ''}
# {'node_id': 3886, 'parent_node_id': 3885, 'type_or_label': 'text()', 'pos': 0, 'value': 'Bruce Sewell'}
# {'node_id': 3886, 'parent_node_id': 3885, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3887, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 23, 'value': '\n'}
# {'node_id': 3888, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 24, 'value': ''}
# {'node_id': 3889, 'parent_node_id': 3888, 'type_or_label': 'text()', 'pos': 0, 'value': 'Sina Tamaddon'}
# {'node_id': 3889, 'parent_node_id': 3888, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3890, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 24, 'value': '\n'}
# {'node_id': 3891, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 25, 'value': ''}
# {'node_id': 3892, 'parent_node_id': 3891, 'type_or_label': 'text()', 'pos': 0, 'value': 'Avie Tevanian'}
# {'node_id': 3892, 'parent_node_id': 3891, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3893, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 25, 'value': '\n'}
# {'node_id': 3894, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 26, 'value': ''}
# {'node_id': 3895, 'parent_node_id': 3894, 'type_or_label': 'text()', 'pos': 0, 'value': 'Ronald Wayne'}
# {'node_id': 3895, 'parent_node_id': 3894, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3896, 'parent_node_id': 3808, 'type_or_label': 'text()', 'pos': 26, 'value': '\n'}
# {'node_id': 3897, 'parent_node_id': 3808, 'type_or_label': 'li', 'pos': 27, 'value': ''}
# {'node_id': 3898, 'parent_node_id': 3897, 'type_or_label': 'text()', 'pos': 0, 'value': 'Steve Wozniak'}
# {'node_id': 3898, 'parent_node_id': 3897, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3899, 'parent_node_id': 3807, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3900, 'parent_node_id': 3744, 'type_or_label': 'div', 'pos': 2, 'value': ''}
# {'node_id': 3901, 'parent_node_id': 3740, 'type_or_label': 'tr', 'pos': 1, 'value': ''}
# {'node_id': 3902, 'parent_node_id': 3901, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3903, 'parent_node_id': 3902, 'type_or_label': 'text()', 'pos': 0, 'value': 'Board of'}
# {'node_id': 3903, 'parent_node_id': 3902, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3904, 'parent_node_id': 3903, 'type_or_label': 'br', 'pos': 0, 'value': ''}
# {'node_id': 3905, 'parent_node_id': 3903, 'type_or_label': 'text()', 'pos': 0, 'value': 'directors'}
# {'node_id': 3906, 'parent_node_id': 3901, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3907, 'parent_node_id': 3906, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3908, 'parent_node_id': 3906, 'type_or_label': 'table', 'pos': 1, 'value': ''}
# {'node_id': 3909, 'parent_node_id': 3908, 'type_or_label': 'tbody', 'pos': 0, 'value': ''}
# {'node_id': 3910, 'parent_node_id': 3909, 'type_or_label': 'tr', 'pos': 0, 'value': ''}
# {'node_id': 3911, 'parent_node_id': 3910, 'type_or_label': 'text()', 'pos': 0, 'value': 'Current'}
# {'node_id': 3911, 'parent_node_id': 3910, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3912, 'parent_node_id': 3910, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3913, 'parent_node_id': 3912, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3913, 'parent_node_id': 3912, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3914, 'parent_node_id': 3913, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 3915, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3916, 'parent_node_id': 3915, 'type_or_label': 'text()', 'pos': 0, 'value': 'Arthur D. Levinson'}
# {'node_id': 3916, 'parent_node_id': 3915, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3917, 'parent_node_id': 3915, 'type_or_label': 'text()', 'pos': 0, 'value': ' (Chairman)'}
# {'node_id': 3918, 'parent_node_id': 3914, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3919, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3920, 'parent_node_id': 3919, 'type_or_label': 'text()', 'pos': 0, 'value': 'Tim Cook'}
# {'node_id': 3920, 'parent_node_id': 3919, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3921, 'parent_node_id': 3919, 'type_or_label': 'text()', 'pos': 0, 'value': ' (CEO)'}
# {'node_id': 3922, 'parent_node_id': 3914, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3923, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3924, 'parent_node_id': 3923, 'type_or_label': 'text()', 'pos': 0, 'value': 'James A. Bell'}
# {'node_id': 3924, 'parent_node_id': 3923, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3925, 'parent_node_id': 3914, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3926, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3927, 'parent_node_id': 3926, 'type_or_label': 'text()', 'pos': 0, 'value': 'Albert Gore Jr.'}
# {'node_id': 3927, 'parent_node_id': 3926, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3928, 'parent_node_id': 3914, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3929, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3930, 'parent_node_id': 3929, 'type_or_label': 'text()', 'pos': 0, 'value': 'Andrea Jung'}
# {'node_id': 3930, 'parent_node_id': 3929, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3931, 'parent_node_id': 3914, 'type_or_label': 'text()', 'pos': 4, 'value': '\n'}
# {'node_id': 3932, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 3933, 'parent_node_id': 3932, 'type_or_label': 'text()', 'pos': 0, 'value': 'Ronald D. Sugar'}
# {'node_id': 3933, 'parent_node_id': 3932, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3934, 'parent_node_id': 3914, 'type_or_label': 'text()', 'pos': 5, 'value': '\n'}
# {'node_id': 3935, 'parent_node_id': 3914, 'type_or_label': 'li', 'pos': 6, 'value': ''}
# {'node_id': 3936, 'parent_node_id': 3935, 'type_or_label': 'text()', 'pos': 0, 'value': 'Susan L. Wagner'}
# {'node_id': 3936, 'parent_node_id': 3935, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3937, 'parent_node_id': 3913, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3938, 'parent_node_id': 3909, 'type_or_label': 'tr', 'pos': 1, 'value': ''}
# {'node_id': 3939, 'parent_node_id': 3938, 'type_or_label': 'text()', 'pos': 0, 'value': 'Former'}
# {'node_id': 3939, 'parent_node_id': 3938, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 3940, 'parent_node_id': 3938, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 3941, 'parent_node_id': 3940, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3941, 'parent_node_id': 3940, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 3942, 'parent_node_id': 3941, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 3943, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 3944, 'parent_node_id': 3943, 'type_or_label': 'text()', 'pos': 0, 'value': 'Mike Markkula'}
# {'node_id': 3944, 'parent_node_id': 3943, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3945, 'parent_node_id': 3943, 'type_or_label': 'text()', 'pos': 0, 'value': ' (Chairman)'}
# {'node_id': 3946, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3947, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 3948, 'parent_node_id': 3947, 'type_or_label': 'text()', 'pos': 0, 'value': 'John Sculley'}
# {'node_id': 3948, 'parent_node_id': 3947, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3949, 'parent_node_id': 3947, 'type_or_label': 'text()', 'pos': 0, 'value': ' (Chairman)'}
# {'node_id': 3950, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 3951, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 3952, 'parent_node_id': 3951, 'type_or_label': 'text()', 'pos': 0, 'value': 'Steve Jobs'}
# {'node_id': 3952, 'parent_node_id': 3951, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3953, 'parent_node_id': 3951, 'type_or_label': 'text()', 'pos': 0, 'value': ' (Chairman)'}
# {'node_id': 3954, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 2, 'value': '\n'}
# {'node_id': 3955, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 3956, 'parent_node_id': 3955, 'type_or_label': 'text()', 'pos': 0, 'value': 'Gil Amelio'}
# {'node_id': 3956, 'parent_node_id': 3955, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3957, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 3958, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 3959, 'parent_node_id': 3958, 'type_or_label': 'text()', 'pos': 0, 'value': 'Fred D. Anderson'}
# {'node_id': 3959, 'parent_node_id': 3958, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3960, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 4, 'value': '\n'}
# {'node_id': 3961, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 3962, 'parent_node_id': 3961, 'type_or_label': 'text()', 'pos': 0, 'value': 'Bill Campbell'}
# {'node_id': 3962, 'parent_node_id': 3961, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3963, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 5, 'value': '\n'}
# {'node_id': 3964, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 6, 'value': ''}
# {'node_id': 3965, 'parent_node_id': 3964, 'type_or_label': 'text()', 'pos': 0, 'value': 'Mickey Drexler'}
# {'node_id': 3965, 'parent_node_id': 3964, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3966, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 6, 'value': '\n'}
# {'node_id': 3967, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 7, 'value': ''}
# {'node_id': 3968, 'parent_node_id': 3967, 'type_or_label': 'text()', 'pos': 0, 'value': 'Al Eisenstat'}
# {'node_id': 3968, 'parent_node_id': 3967, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3969, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 7, 'value': '\n'}
# {'node_id': 3970, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 8, 'value': ''}
# {'node_id': 3971, 'parent_node_id': 3970, 'type_or_label': 'text()', 'pos': 0, 'value': 'Larry Ellison'}
# {'node_id': 3971, 'parent_node_id': 3970, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3972, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 8, 'value': '\n'}
# {'node_id': 3973, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 9, 'value': ''}
# {'node_id': 3974, 'parent_node_id': 3973, 'type_or_label': 'text()', 'pos': 0, 'value': 'Robert A. Iger'}
# {'node_id': 3974, 'parent_node_id': 3973, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3975, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 9, 'value': '\n'}
# {'node_id': 3976, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 10, 'value': ''}
# {'node_id': 3977, 'parent_node_id': 3976, 'type_or_label': 'text()', 'pos': 0, 'value': 'Delano Lewis'}
# {'node_id': 3977, 'parent_node_id': 3976, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3978, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 10, 'value': '\n'}
# {'node_id': 3979, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 11, 'value': ''}
# {'node_id': 3980, 'parent_node_id': 3979, 'type_or_label': 'text()', 'pos': 0, 'value': 'Arthur Rock'}
# {'node_id': 3980, 'parent_node_id': 3979, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3981, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 11, 'value': '\n'}
# {'node_id': 3982, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 12, 'value': ''}
# {'node_id': 3983, 'parent_node_id': 3982, 'type_or_label': 'text()', 'pos': 0, 'value': 'Eric Schmidt'}
# {'node_id': 3983, 'parent_node_id': 3982, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3984, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 12, 'value': '\n'}
# {'node_id': 3985, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 13, 'value': ''}
# {'node_id': 3986, 'parent_node_id': 3985, 'type_or_label': 'text()', 'pos': 0, 'value': 'Michael Scott'}
# {'node_id': 3986, 'parent_node_id': 3985, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3987, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 13, 'value': '\n'}
# {'node_id': 3988, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 14, 'value': ''}
# {'node_id': 3989, 'parent_node_id': 3988, 'type_or_label': 'text()', 'pos': 0, 'value': 'Michael Spindler'}
# {'node_id': 3989, 'parent_node_id': 3988, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3990, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 14, 'value': '\n'}
# {'node_id': 3991, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 15, 'value': ''}
# {'node_id': 3992, 'parent_node_id': 3991, 'type_or_label': 'text()', 'pos': 0, 'value': 'Edgar S. Woolard Jr.'}
# {'node_id': 3992, 'parent_node_id': 3991, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3993, 'parent_node_id': 3942, 'type_or_label': 'text()', 'pos': 15, 'value': '\n'}
# {'node_id': 3994, 'parent_node_id': 3942, 'type_or_label': 'li', 'pos': 16, 'value': ''}
# {'node_id': 3995, 'parent_node_id': 3994, 'type_or_label': 'text()', 'pos': 0, 'value': 'Jerry York'}
# {'node_id': 3995, 'parent_node_id': 3994, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 3996, 'parent_node_id': 3941, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 3997, 'parent_node_id': 3906, 'type_or_label': 'div', 'pos': 2, 'value': ''}
# {'node_id': 3998, 'parent_node_id': 3740, 'type_or_label': 'tr', 'pos': 2, 'value': ''}
# {'node_id': 3999, 'parent_node_id': 3998, 'type_or_label': 'text()', 'pos': 0, 'value': 'Founders'}
# {'node_id': 3999, 'parent_node_id': 3998, 'type_or_label': 'th', 'pos': 0, 'value': ''}
# {'node_id': 4000, 'parent_node_id': 3998, 'type_or_label': 'td', 'pos': 1, 'value': ''}
# {'node_id': 4001, 'parent_node_id': 4000, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 4001, 'parent_node_id': 4000, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 4002, 'parent_node_id': 4001, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 4003, 'parent_node_id': 4002, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 4004, 'parent_node_id': 4003, 'type_or_label': 'text()', 'pos': 0, 'value': 'Steve Jobs'}
# {'node_id': 4004, 'parent_node_id': 4003, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 4005, 'parent_node_id': 4002, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 4006, 'parent_node_id': 4002, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 4007, 'parent_node_id': 4006, 'type_or_label': 'text()', 'pos': 0, 'value': 'Steve Wozniak'}
# {'node_id': 4007, 'parent_node_id': 4006, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 4008, 'parent_node_id': 4002, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 4009, 'parent_node_id': 4002, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 4010, 'parent_node_id': 4009, 'type_or_label': 'text()', 'pos': 0, 'value': 'Ronald Wayne'}
# {'node_id': 4010, 'parent_node_id': 4009, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 4011, 'parent_node_id': 4001, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 4012, 'parent_node_id': 3737, 'type_or_label': 'div', 'pos': 2, 'value': ''}
# {'node_id': 4013, 'parent_node_id': 2952, 'type_or_label': 'tr', 'pos': 7, 'value': ''}
# {'node_id': 4014, 'parent_node_id': 4013, 'type_or_label': 'td', 'pos': 0, 'value': ''}
# {'node_id': 4015, 'parent_node_id': 4014, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 4016, 'parent_node_id': 4015, 'type_or_label': 'div', 'pos': 0, 'value': ''}
# {'node_id': 4017, 'parent_node_id': 4016, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 4018, 'parent_node_id': 4017, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 4019, 'parent_node_id': 4018, 'type_or_label': 'text()', 'pos': 0, 'value': 'Italics'}
# {'node_id': 4019, 'parent_node_id': 4018, 'type_or_label': 'i', 'pos': 0, 'value': ''}
# {'node_id': 4020, 'parent_node_id': 4018, 'type_or_label': 'text()', 'pos': 0, 'value': ' indicate '}
# {'node_id': 4021, 'parent_node_id': 4018, 'type_or_label': 'text()', 'pos': 1, 'value': 'discontinued products, services'}
# {'node_id': 4021, 'parent_node_id': 4018, 'type_or_label': 'a', 'pos': 1, 'value': ''}
# {'node_id': 4022, 'parent_node_id': 4018, 'type_or_label': 'text()', 'pos': 1, 'value': ', or '}
# {'node_id': 4023, 'parent_node_id': 4018, 'type_or_label': 'text()', 'pos': 2, 'value': 'defunct companies'}
# {'node_id': 4023, 'parent_node_id': 4018, 'type_or_label': 'a', 'pos': 2, 'value': ''}
# {'node_id': 4024, 'parent_node_id': 4018, 'type_or_label': 'text()', 'pos': 2, 'value': '.'}
# {'node_id': 4025, 'parent_node_id': 4015, 'type_or_label': 'text()', 'pos': 0, 'value': '\n'}
# {'node_id': 4026, 'parent_node_id': 4015, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 4027, 'parent_node_id': 4026, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 4028, 'parent_node_id': 4027, 'type_or_label': 'img', 'pos': 0, 'value': ''}
# {'node_id': 4029, 'parent_node_id': 4027, 'type_or_label': 'text()', 'pos': 0, 'value': ' '}
# {'node_id': 4030, 'parent_node_id': 4027, 'type_or_label': 'text()', 'pos': 1, 'value': 'Book'}
# ...
# {'node_id': 7268, 'parent_node_id': 7267, 'type_or_label': 'span', 'pos': 0, 'value': ''}
# {'node_id': 7269, 'parent_node_id': 7267, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7270, 'parent_node_id': 7266, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7271, 'parent_node_id': 7266, 'type_or_label': 'text()', 'pos': 1, 'value': '\n\t\t'}
# {'node_id': 7271, 'parent_node_id': 7266, 'type_or_label': 'div', 'pos': 1, 'value': ''}
# {'node_id': 7272, 'parent_node_id': 7271, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 7273, 'parent_node_id': 7272, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 7274, 'parent_node_id': 7273, 'type_or_label': 'text()', 'pos': 0, 'value': 'Download as PDF'}
# {'node_id': 7274, 'parent_node_id': 7273, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7275, 'parent_node_id': 7272, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 7276, 'parent_node_id': 7275, 'type_or_label': 'text()', 'pos': 0, 'value': 'Printable version'}
# {'node_id': 7276, 'parent_node_id': 7275, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7277, 'parent_node_id': 7271, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t\t\n\t'}
# {'node_id': 7278, 'parent_node_id': 7266, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 7279, 'parent_node_id': 7183, 'type_or_label': 'text()', 'pos': 8, 'value': '\n\n\t'}
# {'node_id': 7280, 'parent_node_id': 7183, 'type_or_label': 'text()', 'pos': 9, 'value': ' Please do not use role attribute as CSS selector, it is deprecated. '}
# {'node_id': 7280, 'parent_node_id': 7183, 'type_or_label': <cyfunction Comment at 0x7fa28fda33e0>, 'pos': 9, 'value': ''}
# {'node_id': 7281, 'parent_node_id': 7183, 'type_or_label': 'text()', 'pos': 9, 'value': '\n'}
# {'node_id': 7282, 'parent_node_id': 7183, 'type_or_label': 'text()', 'pos': 10, 'value': '\n\t'}
# {'node_id': 7282, 'parent_node_id': 7183, 'type_or_label': 'nav', 'pos': 10, 'value': ''}
# {'node_id': 7283, 'parent_node_id': 7282, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t\t'}
# {'node_id': 7283, 'parent_node_id': 7282, 'type_or_label': 'h3', 'pos': 0, 'value': ''}
# {'node_id': 7284, 'parent_node_id': 7283, 'type_or_label': 'text()', 'pos': 0, 'value': 'Languages'}
# {'node_id': 7284, 'parent_node_id': 7283, 'type_or_label': 'span', 'pos': 0, 'value': ''}
# {'node_id': 7285, 'parent_node_id': 7283, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7286, 'parent_node_id': 7282, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7287, 'parent_node_id': 7282, 'type_or_label': 'text()', 'pos': 1, 'value': '\n\t\t'}
# {'node_id': 7287, 'parent_node_id': 7282, 'type_or_label': 'div', 'pos': 1, 'value': ''}
# {'node_id': 7288, 'parent_node_id': 7287, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 7289, 'parent_node_id': 7288, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 7290, 'parent_node_id': 7289, 'type_or_label': 'text()', 'pos': 0, 'value': 'العربية'}
# {'node_id': 7290, 'parent_node_id': 7289, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7291, 'parent_node_id': 7288, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 7292, 'parent_node_id': 7291, 'type_or_label': 'text()', 'pos': 0, 'value': 'Deutsch'}
# {'node_id': 7292, 'parent_node_id': 7291, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7293, 'parent_node_id': 7288, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 7294, 'parent_node_id': 7293, 'type_or_label': 'text()', 'pos': 0, 'value': 'Français'}
# {'node_id': 7294, 'parent_node_id': 7293, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7295, 'parent_node_id': 7288, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 7296, 'parent_node_id': 7295, 'type_or_label': 'text()', 'pos': 0, 'value': 'Português'}
# {'node_id': 7296, 'parent_node_id': 7295, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7297, 'parent_node_id': 7288, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 7298, 'parent_node_id': 7297, 'type_or_label': 'text()', 'pos': 0, 'value': 'Shqip'}
# {'node_id': 7298, 'parent_node_id': 7297, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7299, 'parent_node_id': 7288, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 7300, 'parent_node_id': 7299, 'type_or_label': 'text()', 'pos': 0, 'value': '中文'}
# {'node_id': 7300, 'parent_node_id': 7299, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7301, 'parent_node_id': 7287, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t\t'}
# {'node_id': 7302, 'parent_node_id': 7287, 'type_or_label': 'div', 'pos': 1, 'value': ''}
# {'node_id': 7303, 'parent_node_id': 7302, 'type_or_label': 'span', 'pos': 0, 'value': ''}
# {'node_id': 7304, 'parent_node_id': 7303, 'type_or_label': 'text()', 'pos': 0, 'value': 'Edit links'}
# {'node_id': 7304, 'parent_node_id': 7303, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7305, 'parent_node_id': 7287, 'type_or_label': 'text()', 'pos': 1, 'value': '\n\t'}
# {'node_id': 7306, 'parent_node_id': 7282, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 7307, 'parent_node_id': 7183, 'type_or_label': 'text()', 'pos': 10, 'value': '\n\n'}
# {'node_id': 7308, 'parent_node_id': 7073, 'type_or_label': 'text()', 'pos': 2, 'value': '\n\n'}
# {'node_id': 7309, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 4, 'value': '\n'}
# {'node_id': 7310, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 5, 'value': '\n\t'}
# {'node_id': 7310, 'parent_node_id': 5358, 'type_or_label': 'footer', 'pos': 5, 'value': ''}
# {'node_id': 7311, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7311, 'parent_node_id': 7310, 'type_or_label': 'ul', 'pos': 0, 'value': ''}
# {'node_id': 7312, 'parent_node_id': 7311, 'type_or_label': 'text()', 'pos': 0, 'value': ' This page was last edited on 26 January 2021, at 01:12'}
# {'node_id': 7312, 'parent_node_id': 7311, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 7313, 'parent_node_id': 7312, 'type_or_label': 'text()', 'pos': 0, 'value': '\xa0(UTC)'}
# {'node_id': 7313, 'parent_node_id': 7312, 'type_or_label': 'span', 'pos': 0, 'value': ''}
# {'node_id': 7314, 'parent_node_id': 7312, 'type_or_label': 'text()', 'pos': 0, 'value': '.'}
# {'node_id': 7315, 'parent_node_id': 7311, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7316, 'parent_node_id': 7311, 'type_or_label': 'text()', 'pos': 1, 'value': 'Text is available under the '}
# {'node_id': 7316, 'parent_node_id': 7311, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 7317, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 0, 'value': 'Creative Commons Attribution-ShareAlike License'}
# {'node_id': 7317, 'parent_node_id': 7316, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7318, 'parent_node_id': 7316, 'type_or_label': 'a', 'pos': 1, 'value': ''}
# {'node_id': 7319, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 1, 'value': ';\nadditional terms may apply.  By using this site, you agree to the '}
# {'node_id': 7320, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 2, 'value': 'Terms of Use'}
# {'node_id': 7320, 'parent_node_id': 7316, 'type_or_label': 'a', 'pos': 2, 'value': ''}
# {'node_id': 7321, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 2, 'value': ' and '}
# {'node_id': 7322, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 3, 'value': 'Privacy Policy'}
# {'node_id': 7322, 'parent_node_id': 7316, 'type_or_label': 'a', 'pos': 3, 'value': ''}
# {'node_id': 7323, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 3, 'value': '. Wikipedia® is a registered trademark of the '}
# {'node_id': 7324, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 4, 'value': 'Wikimedia Foundation, Inc.'}
# {'node_id': 7324, 'parent_node_id': 7316, 'type_or_label': 'a', 'pos': 4, 'value': ''}
# {'node_id': 7325, 'parent_node_id': 7316, 'type_or_label': 'text()', 'pos': 4, 'value': ', a non-profit organization.'}
# {'node_id': 7326, 'parent_node_id': 7311, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 7327, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\n\t'}
# {'node_id': 7328, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 1, 'value': '\n\t'}
# {'node_id': 7328, 'parent_node_id': 7310, 'type_or_label': 'ul', 'pos': 1, 'value': ''}
# {'node_id': 7329, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 7330, 'parent_node_id': 7329, 'type_or_label': 'text()', 'pos': 0, 'value': 'Privacy policy'}
# {'node_id': 7330, 'parent_node_id': 7329, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7331, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7332, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 7333, 'parent_node_id': 7332, 'type_or_label': 'text()', 'pos': 0, 'value': 'About Wikipedia'}
# {'node_id': 7333, 'parent_node_id': 7332, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7334, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 1, 'value': '\n\t'}
# {'node_id': 7335, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 2, 'value': ''}
# {'node_id': 7336, 'parent_node_id': 7335, 'type_or_label': 'text()', 'pos': 0, 'value': 'Disclaimers'}
# {'node_id': 7336, 'parent_node_id': 7335, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7337, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 2, 'value': '\n\t'}
# {'node_id': 7338, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 3, 'value': ''}
# {'node_id': 7339, 'parent_node_id': 7338, 'type_or_label': 'text()', 'pos': 0, 'value': 'Contact Wikipedia'}
# {'node_id': 7339, 'parent_node_id': 7338, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7340, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 3, 'value': '\n\t'}
# {'node_id': 7341, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 4, 'value': ''}
# {'node_id': 7342, 'parent_node_id': 7341, 'type_or_label': 'text()', 'pos': 0, 'value': 'Mobile view'}
# {'node_id': 7342, 'parent_node_id': 7341, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7343, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 4, 'value': '\n\t'}
# {'node_id': 7344, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 5, 'value': ''}
# {'node_id': 7345, 'parent_node_id': 7344, 'type_or_label': 'text()', 'pos': 0, 'value': 'Developers'}
# {'node_id': 7345, 'parent_node_id': 7344, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7346, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 5, 'value': '\n\t'}
# {'node_id': 7347, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 6, 'value': ''}
# {'node_id': 7348, 'parent_node_id': 7347, 'type_or_label': 'text()', 'pos': 0, 'value': 'Statistics'}
# {'node_id': 7348, 'parent_node_id': 7347, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7349, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 6, 'value': '\n\t'}
# {'node_id': 7350, 'parent_node_id': 7328, 'type_or_label': 'li', 'pos': 7, 'value': ''}
# {'node_id': 7351, 'parent_node_id': 7350, 'type_or_label': 'text()', 'pos': 0, 'value': 'Cookie statement'}
# {'node_id': 7351, 'parent_node_id': 7350, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7352, 'parent_node_id': 7328, 'type_or_label': 'text()', 'pos': 7, 'value': '\n'}
# {'node_id': 7353, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 1, 'value': '\n\n\t'}
# {'node_id': 7354, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 2, 'value': '\n\t'}
# {'node_id': 7354, 'parent_node_id': 7310, 'type_or_label': 'ul', 'pos': 2, 'value': ''}
# {'node_id': 7355, 'parent_node_id': 7354, 'type_or_label': 'li', 'pos': 0, 'value': ''}
# {'node_id': 7356, 'parent_node_id': 7355, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7357, 'parent_node_id': 7356, 'type_or_label': 'img', 'pos': 0, 'value': ''}
# {'node_id': 7358, 'parent_node_id': 7354, 'type_or_label': 'text()', 'pos': 0, 'value': '\n\t'}
# {'node_id': 7359, 'parent_node_id': 7354, 'type_or_label': 'li', 'pos': 1, 'value': ''}
# {'node_id': 7360, 'parent_node_id': 7359, 'type_or_label': 'a', 'pos': 0, 'value': ''}
# {'node_id': 7361, 'parent_node_id': 7360, 'type_or_label': 'img', 'pos': 0, 'value': ''}
# {'node_id': 7362, 'parent_node_id': 7354, 'type_or_label': 'text()', 'pos': 1, 'value': '\n'}
# {'node_id': 7363, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 2, 'value': '\n\n\t'}
# {'node_id': 7364, 'parent_node_id': 7310, 'type_or_label': 'div', 'pos': 3, 'value': ''}
# {'node_id': 7365, 'parent_node_id': 7310, 'type_or_label': 'text()', 'pos': 3, 'value': '\n'}
# {'node_id': 7366, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 5, 'value': '\n\n\n'}
# {'node_id': 7367, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 6, 'value': '(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.788","walltime":"0.956","ppvisitednodes":{"value":2781,"limit":1000000},"postexpandincludesize":{"value":103408,"limit":2097152},"templateargumentsize":{"value":1844,"limit":2097152},"expansiondepth":{"value":20,"limit":40},"expensivefunctioncount":{"value":4,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":84384,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  816.753      1 -total"," 49.20%  401.819      1 Template:Reflist"," 28.46%  232.418      1 Template:Infobox_company"," 25.72%  210.109      1 Template:Infobox"," 18.92%  154.496      1 Template:In_lang"," 17.24%  140.781     11 Template:Cite_news","  8.03%   65.549      1 Template:Official_URL","  7.82%   63.910     12 Template:Cite_web","  7.63%   62.323      5 Template:Navbox","  6.16%   50.338      1 Template:Facebook_navbox"]},"scribunto":{"limitreport-timeusage":{"value":"0.455","limit":"10.000"},"limitreport-memusage":{"value":18529078,"limit":52428800}},"cachereport":{"origin":"mw1328","timestamp":"20210202183935","ttl":2592000,"transientcontent":false}}});});'}
# {'node_id': 7367, 'parent_node_id': 5358, 'type_or_label': 'script', 'pos': 6, 'value': ''}
# {'node_id': 7368, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 6, 'value': '\n'}
# {'node_id': 7369, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 7, 'value': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Chan Zuckerberg Initiative","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Chan_Zuckerberg_Initiative","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q21623039","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q21623039","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2015-12-02T23:37:57Z","dateModified":"2021-01-26T01:12:45Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/en\\/a\\/ae\\/Chan_Zuckerberg_Initiative.svg","headline":"company founded by Marc Zuckerberg and Priscilla Chan"}'}
# {'node_id': 7369, 'parent_node_id': 5358, 'type_or_label': 'script', 'pos': 7, 'value': ''}
# {'node_id': 7370, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 7, 'value': '\n'}
# {'node_id': 7371, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 8, 'value': '(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":106,"wgHostname":"mw1401"});});'}
# {'node_id': 7371, 'parent_node_id': 5358, 'type_or_label': 'script', 'pos': 8, 'value': ''}
# {'node_id': 7372, 'parent_node_id': 5358, 'type_or_label': 'text()', 'pos': 8, 'value': '\n'}
#                                                  url root_id
# 0             https://en.wikipedia.org/wiki/Tim_Cook       0
# 1  https://en.wikipedia.org/wiki/Chan_Zuckerberg_...    5305

# %%
node_df
# Out:
#      node_id parent_node_id type_or_label pos value
# 0          0           None          html   0
# 1          1              0          head   0
# 2          2              1          meta   0
# 3          3              1        text()   0    \n
# 4          4              1         title   1
# ...      ...            ...           ...  ..   ...
# 7368    7368           5358        text()   6    \n
# 7369    7369           5358        script   7
# 7370    7370           5358        text()   7    \n
# 7371    7371           5358        script   8
# 7372    7372           5358        text()   8    \n
#
# [7373 rows x 5 columns]

# %%
pages_df
# Out:
#                                                  url root_id
# 0             https://en.wikipedia.org/wiki/Tim_Cook       0
# 1  https://en.wikipedia.org/wiki/Chan_Zuckerberg_...    5305

# %%
# Find all document roots
pages_df.merge(node_df,left_on=['root_id'],right_on=['node_id'])
# Out:
#                                                  url root_id  ... pos value
# 0             https://en.wikipedia.org/wiki/Tim_Cook       0  ...   0
# 1  https://en.wikipedia.org/wiki/Chan_Zuckerberg_...    5305  ...   0
#
# [2 rows x 7 columns]

# %%
# Find all text() nodes inside of <p> tags

node_df[node_df['type_or_label']=='p'][['node_id']].\
    merge(node_df[node_df['type_or_label']=='text()'], \
          left_on=['node_id'], right_on=['parent_node_id'])[['value']]
# Out:
#                                                  value
# 0                              (born November 1, 1960)
# 1     is an American business executive, philanthro...
# 2                                       . Cook is the
# 3                                                  of
# 4            , and previously served as the company's
# ..                                                 ...
# 251   and has fewer other transparency requirements...
# 252                    Under this legal structure, as
# 253   wrote it, "Zuckerberg will still control the ...
# 254   The Chan Zuckerberg Initiative publicly lists...
# 255                                                 \n
#
# [256 rows x 1 columns]

# %%
p_text_nodes = node_df[node_df['type_or_label']=='p'][['parent_node_id','node_id']].\
    merge(node_df[node_df['type_or_label']=='text()'][['parent_node_id','node_id']], \
          left_on=['node_id'], right_on=['parent_node_id']).\
    rename(columns={'parent_node_id_x': 'ancestor_node_id', 'node_id_y': 'text_node_id'})

p_text_nodes
# Out:
#     ancestor_node_id node_id_x parent_node_id_y text_node_id
# 0                 82       181              181          183
# 1                 82       181              181          186
# 2                 82       181              181          188
# 3                 82       181              181          190
# 4                 82       181              181          192
# ..               ...       ...              ...          ...
# 251             5387      5725             5725         5751
# 252             5387      5725             5725         5760
# 253             5387      5725             5725         5763
# 254             5387      5725             5725         5768
# 255             5387      5725             5725         5771
#
# [256 rows x 4 columns]

# %%
current_items_df = p_text_nodes

parents_df = current_items_df[['ancestor_node_id','text_node_id']].\
    merge(node_df,\
    left_on=['ancestor_node_id'],right_on=['node_id'])\
    [['parent_node_id','text_node_id']].\
rename(columns={'parent_node_id': 'ancestor_node_id'})

parents_df
# Out:
#     ancestor_node_id text_node_id
# 0                 81          183
# 1                 81          186
# 2                 81          188
# 3                 81          190
# 4                 81          192
# ..               ...          ...
# 251             5386         5751
# 252             5386         5760
# 253             5386         5763
# 254             5386         5768
# 255             5386         5771
#
# [256 rows x 2 columns]

# %%
current_items_df = parents_df

grandparents_df = current_items_df[['ancestor_node_id','text_node_id']].drop_duplicates().\
    merge(node_df,\
    left_on=['ancestor_node_id'],right_on=['node_id'])\
    [['parent_node_id','text_node_id']].\
rename(columns={'parent_node_id': 'ancestor_node_id'}).drop_duplicates()

grandparents_df
# Out:
#     ancestor_node_id text_node_id
# 0                 68          183
# 1                 68          186
# 2                 68          188
# 3                 68          190
# 4                 68          192
# ..               ...          ...
# 251             5373         5751
# 252             5373         5760
# 253             5373         5763
# 254             5373         5768
# 255             5373         5771
#
# [256 rows x 2 columns]

# %%
def find_ancestor_nodes(node_df, current_items_df):
    if len(current_items_df) == 0:
        return current_items_df
    else:
        parents_df = current_items_df[['ancestor_node_id','text_node_id']].drop_duplicates().\
            merge(node_df,\
            left_on=['ancestor_node_id'],right_on=['node_id'])\
            [['parent_node_id','text_node_id']].\
        rename(columns={'parent_node_id': 'ancestor_node_id'}).drop_duplicates()

        return pd.concat([parents_df,find_ancestor_nodes(node_df, parents_df)]).drop_duplicates()

nodes_ancestors = find_ancestor_nodes(node_df, p_text_nodes)

nodes_ancestors
# Out:
#     ancestor_node_id text_node_id
# 0                 81          183
# 1                 81          186
# 2                 81          188
# 3                 81          190
# 4                 81          192
# ..               ...          ...
# 251             None         5751
# 252             None         5760
# 253             None         5763
# 254             None         5768
# 255             None         5771
#
# [1536 rows x 2 columns]

# %%
# Can we find ONLY text from the Tim Cook document?

nodes_ancestors[nodes_ancestors['ancestor_node_id']==0].\
    merge(node_df, left_on=['text_node_id'],right_on=['node_id'])[['value']]
# Out:
#                                                  value
# 0                              (born November 1, 1960)
# 1     is an American business executive, philanthro...
# 2                                       . Cook is the
# 3                                                  of
# 4            , and previously served as the company's
# ..                                                 ...
# 183   before him that paved the way for his success...
# 184                  He hoped his openness could help
# 185                                             , and
# 186        hope that their situation could get better.
# 187                                                 \n
#
# [188 rows x 1 columns]

# %% [markdown]
# # Big Data Takes a Long Time to Process
#
# Now that we've seen how to do fairly complex queries over data in relations, we'll "pop back" to our big data example, which is the LinkedIn dataset.  Recall that we had a segment of the LinkedIn input file in our previous examples earlier in this module.

# %%
# %%time
# 100,000 records from linkedin
linked_in = open('/content/linkedin_small.json.txt')

people = []

for line in linked_in:
    person = json.loads(line)
    people.append(person)

people_df = pd.DataFrame(people)
people_df[people_df['industry'] == 'Medical Devices']
# Out:
# CPU times: user 9.95 s, sys: 324 ms, total: 10.3 s
# Wall time: 10.4 s

# %%
# %%time
# 100,000 records from linkedin
linked_in = open('/content/linkedin_small.json.txt')

people = []

for line in linked_in:
    person = json.loads(line)
    if 'industry' in person and person['industry'] == 'Medical Devices':
        people.append(person)

people_df = pd.DataFrame(people)
people_df
# Out:
# CPU times: user 7.31 s, sys: 213 ms, total: 7.53 s
# Wall time: 7.58 s

# %% [markdown]
# ## SQL query without an index
#
# SQL databases will automatically "push down" selection and projection where feasible.  They also don't need to parse.

# %%
conn = sqlite3.connect('linkedin.db')

## This is just to reset things so we don't have an index
conn.execute('begin transaction')
conn.execute('drop index if exists people_industry')
conn.execute('commit')

# %%
# %%time

pd.read_sql_query('select * from people where industry="Medical Devices"', conn)
# Out:
# CPU times: user 6.24 ms, sys: 4.05 ms, total: 10.3 ms
# Wall time: 10.6 ms
#                        _id  ... homepage
# 0              in-00000001  ...
# 1           in-13806219531  ...
# 2       in-1scottsanderson  ...
# 3             in-2008annvu  ...
# 4            in-2johnstroh  ...
# 5            in-4mikeoshea  ...
# 6                in-aabose  ...
# 7             in-aarisrand  ...
# 8           in-aaronburton  ...
# 9            in-aaronmback  ...
# 10           in-abbasbohra  ...
# 11            in-abbypratt  ...
# 12           in-abefadakar  ...
# 13              in-abelang  ...
# 14  in-abhilashchakraverty  ...
# 15        in-abhinavramani  ...
# 16         in-abhinnagupta  ...
# 17       in-abhishekgautam  ...
# 18                in-acaru  ...
# 19            in-accetturo  ...
# 20                in-acheb  ...
# 21         in-acunanarvaez  ...
# 22           in-adamazzara  ...
# 23            in-adambrody  ...
# 24   in-adamfrilotwilliams  ...
# 25        in-adamgrabowski  ...
# 26         in-adamjacobson  ...
# 27     in-adamkalbermatten  ...
# 28           in-adamsummer  ...
# 29             in-adavenpo  ...
# 30       in-adityapolasani  ...
# 31           in-adrianroji  ...
# 32         in-advclinicals  ...
# 33              in-aganesh  ...
# 34              in-agupta5  ...
# 35             in-aharrold  ...
# 36         in-ahmadghaddar  ...
# 37            in-ahosseini  ...
# 38           in-aidancasey  ...
# 39               in-aislyn  ...
# 40           in-ajackerman  ...
# 41          in-ajosephkatz  ...
# 42       in-ajosephprofile  ...
# 43             in-akarnold  ...
# 44       in-akhildeshpande  ...
# 45           in-akoslowsky  ...
# 46               in-akumar  ...
# 47         in-alanfinnerty  ...
# 48              in-alanhow  ...
# 49     in-alanlucasbradley  ...
# 50          in-alanmcnulty  ...
# 51     in-alanscivolutions  ...
# 52        in-alasdarbrowne  ...
# 53          in-alaybhayani  ...
#
# [54 rows x 9 columns]

# %% [markdown]
# ## Let's build an index now...
#
# This should somewhat speed up the SQL query

# %%
conn = sqlite3.connect('linkedin.db')

conn.execute('begin transaction')
conn.execute('drop index if exists people_industry')
conn.execute("create index people_industry on people(industry)")
conn.execute('commit')

# %%
# %%time
# Treat the view as a table, see what's there
pd.read_sql_query('select * from people where industry="Medical Devices"', conn)

# In our tests, this was 5x faster!
# Out:
# CPU times: user 3.08 ms, sys: 974 µs, total: 4.06 ms
# Wall time: 5.24 ms
#                        _id  ... homepage
# 0              in-00000001  ...
# 1           in-13806219531  ...
# 2       in-1scottsanderson  ...
# 3             in-2008annvu  ...
# 4            in-2johnstroh  ...
# 5            in-4mikeoshea  ...
# 6                in-aabose  ...
# 7             in-aarisrand  ...
# 8           in-aaronburton  ...
# 9            in-aaronmback  ...
# 10           in-abbasbohra  ...
# 11            in-abbypratt  ...
# 12           in-abefadakar  ...
# 13              in-abelang  ...
# 14  in-abhilashchakraverty  ...
# 15        in-abhinavramani  ...
# 16         in-abhinnagupta  ...
# 17       in-abhishekgautam  ...
# 18                in-acaru  ...
# 19            in-accetturo  ...
# 20                in-acheb  ...
# 21         in-acunanarvaez  ...
# 22           in-adamazzara  ...
# 23            in-adambrody  ...
# 24   in-adamfrilotwilliams  ...
# 25        in-adamgrabowski  ...
# 26         in-adamjacobson  ...
# 27     in-adamkalbermatten  ...
# 28           in-adamsummer  ...
# 29             in-adavenpo  ...
# 30       in-adityapolasani  ...
# 31           in-adrianroji  ...
# 32         in-advclinicals  ...
# 33              in-aganesh  ...
# 34              in-agupta5  ...
# 35             in-aharrold  ...
# 36         in-ahmadghaddar  ...
# 37            in-ahosseini  ...
# 38           in-aidancasey  ...
# 39               in-aislyn  ...
# 40           in-ajackerman  ...
# 41          in-ajosephkatz  ...
# 42       in-ajosephprofile  ...
# 43             in-akarnold  ...
# 44       in-akhildeshpande  ...
# 45           in-akoslowsky  ...
# 46               in-akumar  ...
# 47         in-alanfinnerty  ...
# 48              in-alanhow  ...
# 49     in-alanlucasbradley  ...
# 50          in-alanmcnulty  ...
# 51     in-alanscivolutions  ...
# 52        in-alasdarbrowne  ...
# 53          in-alaybhayani  ...
#
# [54 rows x 9 columns]

# %%
conn = sqlite3.connect('linkedin.db')

people_df = pd.read_sql_query('select * from people limit 500', conn)
experience_df = pd.read_sql_query('select * from experience limit 5000', conn)
skills_df = pd.read_sql_query('select * from skills limit 8000', conn)

print ("%d people"%len(people_df))
print ("%d experiences"%len(experience_df))
print ("%d skills"%len(skills_df))
# Out:
# 500 people
# 5000 experiences
# 8000 skills

# %%
def merge(S,T,l_on,r_on):
    ret = pd.DataFrame()
    count = 0
    for s_index in range(0, len(S)):
        for t_index in range(0, len(T)):
            count = count + 1
            if S.loc[s_index, l_on] == T.loc[t_index, r_on]:
                ret = ret.append(S.loc[s_index].append(T.loc[t_index].drop(labels=r_on)), ignore_index=True)

    print('Merge compared %d tuples'%count)
    return ret

# %%
# %%time
# Here's a test join, with people and their experiences.  We can see how many
# comparisons are made

merge(people_df, experience_df, '_id', 'person')
# Out:
# Merge compared 2500000 tuples
# CPU times: user 51.3 s, sys: 31.9 ms, total: 51.3 s
# Wall time: 51.6 s
#              _id  ...                                url
# 0       in-00001  ...    http://be.linkedin.com/in/00001
# 1       in-00001  ...    http://be.linkedin.com/in/00001
# 2       in-00001  ...    http://be.linkedin.com/in/00001
# 3       in-00001  ...    http://be.linkedin.com/in/00001
# 4       in-00001  ...    http://be.linkedin.com/in/00001
# ...          ...  ...                                ...
# 2223  in-3256068  ...  http://cn.linkedin.com/in/3256068
# 2224  in-3256068  ...  http://cn.linkedin.com/in/3256068
# 2225  in-3256068  ...  http://cn.linkedin.com/in/3256068
# 2226  in-3256068  ...  http://cn.linkedin.com/in/3256068
# 2227  in-3256068  ...  http://cn.linkedin.com/in/3256068
#
# [2228 rows x 15 columns]

# %%
# Let's find all people (by ID) who have Marketing as a skill

mktg_df = skills_df[skills_df['value'] == 'Marketing'].reset_index()[['person']]
mktg_df
# Out:
#                     person
# 0              in-01011985
# 1            in-01mihaipop
# 2          in-021370900310
# 3              in-02k17m87
# 4            in-0311101678
# 5   in-05stephaniemartinez
# 6            in-12magazine
# 7              in-140hours
# 8                 in-19655
# 9            in-1alyssalee
# 10        in-1areauntaylor
# 11            in-1devverma
# 12             in-1iankerr
# 13           in-1jeffmeyer
# 14          in-1rickcooper
# 15            in-2008sacks
# 16              in-3256068
# 17               in-4ashby
# 18        in-6028blakeford
# 19       in-71toddphillips
# 20      in-808karenelsmore
# 21            in-916movers
# 22    in-9tot3vacaturebank

# %%
# %%time
merge(merge(people_df, experience_df, '_id', 'person'), mktg_df, '_id', 'person')
# Out:
# Merge compared 2500000 tuples
# Merge compared 51244 tuples
# CPU times: user 54.3 s, sys: 57.5 ms, total: 54.4 s
# Wall time: 55.6 s
#               _id  ...                                   url
# 0     in-01011985  ...    http://in.linkedin.com/in/01011985
# 1   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# 2   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# 3   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# 4   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# ..            ...  ...                                   ...
# 75     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 76     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 77     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 78     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 79     in-3256068  ...     http://cn.linkedin.com/in/3256068
#
# [80 rows x 15 columns]

# %%
# %%time
merge(merge(people_df, mktg_df, '_id', 'person'), experience_df, '_id', 'person')
# Out:
# Merge compared 11500 tuples
# Merge compared 85000 tuples
# CPU times: user 2.35 s, sys: 8.01 ms, total: 2.36 s
# Wall time: 2.61 s
#               _id  ...                                   url
# 0     in-01011985  ...    http://in.linkedin.com/in/01011985
# 1   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# 2   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# 3   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# 4   in-01mihaipop  ...  http://ro.linkedin.com/in/01mihaipop
# ..            ...  ...                                   ...
# 75     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 76     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 77     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 78     in-3256068  ...     http://cn.linkedin.com/in/3256068
# 79     in-3256068  ...     http://cn.linkedin.com/in/3256068
#
# [80 rows x 15 columns]

# %%
experience_df.loc[0].drop(labels='person')
# Out:
# org                                    Johnson and Johnson
# title                Senior Scientist, Oncology Biomarkers
# end                                                Present
# start                                        November 2009
# desc     Biomarker Leader for compounds in clinical dev...
# pos                                                      0
# Name: 0, dtype: object

# %%
# %%time

conn.execute('drop view if exists people500')
conn.execute('drop view if exists experience5000')
conn.execute('drop view if exists skills8000')
conn.execute('create view people500 as select * from people limit 500')
conn.execute('create view experience5000 as select * from experience limit 500')
conn.execute('create view skills8000 as select * from skills limit 500')

pd.read_sql_query('select * from (people500 join skills8000 on _id=person) ps join ' + \
                  'experience5000 ex on ps._id=ex.person and value="Marketing"', conn)
# Out:
# CPU times: user 9.5 ms, sys: 4.98 ms, total: 14.5 ms
# Wall time: 54.7 ms

# %%
# Join using a *map*, which is a kind of in-memory index
# from keys to (single) values
def merge_map(S,T,l_on,r_on):
    ret = pd.DataFrame()
    T_map = {}
    count = 0
    # Take each value in the r_on field, and
    # make a map entry for it
    for t_index in range(0, len(T)):
        # Make sure we aren't overwriting an entry!
        assert (T.loc[t_index,r_on] not in T_map)
        T_map[T.loc[t_index,r_on]] = T.loc[t_index]
        count = count + 1

    # Now find matches
    for s_index in range(0, len(S)):
        count = count + 1
        if S.loc[s_index, l_on] in T_map:
                ret = ret.append(S.loc[s_index].append(T_map[S.loc[s_index, l_on]].drop(labels=r_on)), ignore_index=True)

    print('Merge compared %d tuples'%count)
    return ret

# %%
# %%time

# Here's a test join, with people and their experiences.  We can see how many
# comparisons are made
merge_map(experience_df, people_df, 'person', '_id')
# Out:
# Merge compared 5500 tuples
# CPU times: user 14.2 s, sys: 39.9 ms, total: 14.3 s
# Wall time: 14.7 s
#                                                    desc  ...                                url
# 0     Biomarker Leader for compounds in clinical dev...  ...    http://be.linkedin.com/in/00001
# 1                          Single Cell Gene expression.  ...    http://be.linkedin.com/in/00001
# 2     Work on peptide to restore wt p53 function in ...  ...    http://be.linkedin.com/in/00001
# 3             Molecular profiling of colorectal cancer.  ...    http://be.linkedin.com/in/00001
# 4     Cancer Research at Dept of Surgery.Molecular p...  ...    http://be.linkedin.com/in/00001
# ...                                                 ...  ...                                ...
# 2223  Develops and maintains business relationship w...  ...  http://cn.linkedin.com/in/3256068
# 2224  Assists the store manager in executing store o...  ...  http://cn.linkedin.com/in/3256068
# 2225                                                     ...  http://cn.linkedin.com/in/3256068
# 2226  Hires and trains marketing coordinatorsDevelop...  ...  http://cn.linkedin.com/in/3256068
# 2227  Hires and trains marketing coordinatorsDevelop...  ...  http://cn.linkedin.com/in/3256068
#
# [2228 rows x 15 columns]

# %%
# %%time

# An exercise: how can you modify merge_map to make this work?
merge_map(people_df, experience_df, '_id', 'person')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-41-ad0a007129a7> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', "\n# An exercise: how can you modify merge_map to make this work?\nmerge_map(people_df, experience_df, '_id', 'person')")
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-39-f0f1acf033c0> in merge_map(S, T, l_on, r_on)
#       9     for t_index in range(0, len(T)):
#      10         # Make sure we aren't overwriting an entry!
# ---> 11         assert (T.loc[t_index,r_on] not in T_map)
#      12         T_map[T.loc[t_index,r_on]] = T.loc[t_index]
#      13         count = count + 1
#
# AssertionError:

# %%
# %%time

def slow_op(x):
    # Simulate doing something that takes 100msec
    time.sleep(0.1)
    return x

# Apply the slow_op to each row (across the cols)
people_df.apply(slow_op,axis='columns')

# %%
# %%time

# Apply the slow_op to each row (across the cols)
people_df.swifter.apply(slow_op,axis='columns')
